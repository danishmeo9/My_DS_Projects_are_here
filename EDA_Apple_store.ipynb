# %% [markdown]
# # **EDA On Apple App Store Dataset**

# %% [markdown]
# <h1 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨‍💻Author: Danish Javaid Meo</h1>

# %% [markdown]
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/danishjmeo)
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/danishmeo9)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/danish-javaid-4271a8231/)

# %% [markdown]
# <!-- <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSph3GzuGE3aWSdIK0Bry_fs0o2qamyDFW9Dg&s" alt="EDA" width="700"> -->

# %% [markdown]
# # Data Description
#
# ### Apple AppStore App data of 1.2 Million+ applications
#
# > The Data Set was downloaded from Kaggle, from the following [link](https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps/data)

# %% [markdown]
# | Column Name                | Description                                                  |
# |----------------------------|--------------------------------------------------------------|
# | App_Id                | Unique identifier for each app in the dataset.              |
# | App_Name               | The name of the app as it appears on the App Store.        |
# | AppStore_Url            | Direct URL link to the app's page on the Apple App Store.  |
# | Primary_Genre           | Main category or genre of the app.                          |
# | Content_Rating          | Age rating assigned to the app.                              |
# | Size_Bytes           | Size of the app in bytes.                                   |
# | Required_IOS_Version    | Minimum iOS version required to run the app.                |
# | Released                | Date when the app was first released.                       |
# | Updated                 | Date of the most recent update to the app.                  |
# | Version                 | Current version number of the app.                           |
# | Price                   | Cost of the app, if applicable.                             |
# | Currency                | Currency in which the app's price is listed.                |
# | Free                    | Indicates whether the app is available for free (True/False).|
# | DeveloperId            | Unique identifier for the developer of the app.             |
# | Developer               | Name of the developer or company that created the app.      |
# | Developer_Url            | URL link to the developer's page or profile.                |
# | Developer_Website      | Official website of the developer or company.               |
# | Average_User_Rating      | Average rating given by users for the app.                  |
# | Reviews                 | Total number of user reviews submitted for the app.         |
# | Current_Version_Score    | Average rating score for the current version of the app.    |
# | Current_Version_Reviews  | Number of reviews specific to the current version of the app.|

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno
# from statsmodels.tsa.seasonal import seasonal_decompose
import plotly.graph_objects as go
print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %% [markdown]
# # Load Data Set

# %%
# let's load the
# dataset
df=pd.read_csv("./data/APPLE.csv")

# %%
df.head(3)
# Out:
#                 App_Id        App_Name  \
# 0  com.hkbu.arc.apaper  A+ Paper Guide
# 1  com.dmitriev.abooks         A-Books
# 2       no.terp.abooks         A-books
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# 1             4+  13135872.0                 10.0  2015-08-31T19:31:32Z
# 2             4+  21943296.0                  9.0  2021-04-14T07:00:00Z
#
#                 Updated Version  ...  Currency  Free  DeveloperId  \
# 0  2018-12-21T21:30:36Z   1.1.2  ...       USD  True   1375410542
# 1  2019-07-23T20:31:09Z     1.3  ...       USD  True   1031572001
# ...

# %% [markdown]
# > **Note**:
#     Some the output of notebook does not present the complete output, therefore we can increase the limit of columns view and row view by using these commands:

# %%
pd.set_option('display.max_columns', None) # this is to display all the columns in the dataframe
pd.set_option('display.max_rows', None) # this is to display all the rows in the dataframe

# %%
# check column names
print(f"The names of columns in this dataset are as follows : {df.columns}")
# Out:
# The names of columns in this dataset are as follows : Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %%
# check shape of dataset
print(f"The number of rows are {df.shape[0]},and columns are {df.shape[1]}")
# Out:
# The number of rows are 1230376,and columns are 21

# %% [markdown]
# # Info about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# ## Check the summary of data

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# ----
# ----

# %% [markdown]
# #  **Dealing with Missing Values**

# %%
# find missing values percentage in data
round(df.isnull().sum()/len(df)*100,2).sort_values(ascending=False)
# Out:
# Developer_Website          52.34
# Developer_Url               0.09
# Price                       0.04
# Size_Bytes                  0.02
# App_Id                      0.00
# Content_Rating              0.00
# Primary_Genre               0.00
# AppStore_Url                0.00
# App_Name                    0.00
# Updated                     0.00
# Version                     0.00
# Released                    0.00
# Required_IOS_Version        0.00
# Free                        0.00
# Currency                    0.00
# Developer                   0.00
# DeveloperId                 0.00
# Average_User_Rating         0.00
# Reviews                     0.00
# Current_Version_Score       0.00
# Current_Version_Reviews     0.00
# dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Website          643988
# Developer_Url                1109
# Price                         490
# Size_Bytes                    224
# Released                        3
# App_Name                        1
# Primary_Genre                   0
# AppStore_Url                    0
# App_Id                          0
# Content_Rating                  0
# Version                         0
# Updated                         0
# Required_IOS_Version            0
# Free                            0
# Currency                        0
# Developer                       0
# DeveloperId                     0
# Average_User_Rating             0
# Reviews                         0
# Current_Version_Score           0
# Current_Version_Reviews         0
# dtype: int64

# %%
# make a figure size
plt.figure(figsize=(16, 6))
#plot the null values in each column
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis') # this will show the heatmap of null values in the dataframe
# Out:
# <Axes: >

# %%
missing_percentage = df.isnull().sum() / len(df) * 100
plt.figure(figsize=(16, 6)) # make figure size
missing_percentage[missing_percentage < 1].plot(kind='bar') # plot the null values by their percentage in each column
plt.xlabel('Columns') # add the x-axis labels
plt.ylabel('Percentage') # add the labels for y-axis
plt.title('Percentage of Missing Values in each Column without Rating column')  # add the title for the plot
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column without Rating column')

# %% [markdown]
# - we got main information about this column that ,mostly developer do not provide thier website link, from `1.2` million data 643988 about 52% developers do not provided the websites. so we have to remove this  column

# %%
# drop developer website column
df.drop(columns=['Developer_Website'],inplace=True)
print("Developer_Website column dropped successfully!")
# Out:
# Developer_Website column dropped successfully!

# %% [markdown]
# #### Change the size bytes to MB

# %%
# change the name of the column to Size_Mb 
df.rename(columns={'Size_Bytes': 'Size_Mb'}, inplace=True)

# convert bytes to Mb
df['Size_Mb'] = df['Size_Mb']/1000000\

# round the Size_Mb to 2 decimal places
df['Size_Mb'] = df['Size_Mb'].round(2)

# %% [markdown]
# # Correlation

# %% [markdown]
# - Before filling missing values.we have to see the price column and size column s linked with any column or not

# %%
# Make a correlation matrix of numeric columns
plt.figure(figsize=(16, 10)) # make figure size  
numeric_cols = ['Current_Version_Score', 'Reviews', 'Average_User_Rating', 'Price', 'Size_Mb'] # make a list of numeric columns
sns.heatmap(df[numeric_cols].corr(), annot=True) # plot the correlation matrix
# Out:
# <Axes: >

# %%
# we can also calculate the correlation matrix using pandas
df[numeric_cols].corr() # this will show the correlation matrix
# Out:
#                        Current_Version_Score   Reviews  Average_User_Rating  \
# Current_Version_Score               1.000000  0.022167             1.000000
# Reviews                             0.022167  1.000000             0.022167
# Average_User_Rating                 1.000000  0.022167             1.000000
# Price                              -0.010444 -0.001088            -0.010444
# Size_Mb                             0.048478  0.011250             0.048478
#
#                           Price   Size_Mb
# Current_Version_Score -0.010444  0.048478
# Reviews               -0.001088  0.011250
# Average_User_Rating   -0.010444  0.048478
# Price                  1.000000  0.056338
# Size_Mb                0.056338  1.000000

# %% [markdown]
# # Filling  Missing values

# %%
# Replacing NaN values in numerical columns with the median
df['Price'] = df['Price'].fillna(df['Price'].median())
df['Size_Mb'] = df['Size_Mb'].fillna(df['Size_Mb'].median())

# Replacing NaN values in categorical/string columns
df['Developer_Url'] = df['Developer_Url'].fillna('Unknown')
df['Released'] = df['Released'].fillna(df['Released'].mode()[0])
df['AppStore_Url'] = df['AppStore_Url'].fillna('Unknown')
df['App_Name'] = df['App_Name'].fillna('Unknown')

# Display the result
print(df.isnull().sum())  # Verify no missing values remain
# Out:
# App_Id                     0
# App_Name                   0
# AppStore_Url               0
# Primary_Genre              0
# Content_Rating             0
# Size_Mb                    0
# Required_IOS_Version       0
# Released                   0
# Updated                    0
# Version                    0
# Price                      0
# Currency                   0
# Free                       0
# DeveloperId                0
# Developer                  0
# Developer_Url              0
# Average_User_Rating        0
# Reviews                    0
# Current_Version_Score      0
# Current_Version_Reviews    0
# dtype: int64

# %% [markdown]
# ----

# %%
# Let's check price column minimum and max values
print(f"The minimum price of an app is {df['Price'].min()} and maximum price of an app is ${df['Price'].max()}")
# Out:
# The minimum price of an app is 0.0 and maximum price of an app is $999.99

# %% [markdown]
# <span style="color: yellow; font-size: 350%; font-weight: bold;">Insights</span>

# %% [markdown]
# # ` 🔄 Top 10 Developers`

# %%
# Get the top 10 developers  
top_10_developers = df['Developer'].value_counts().head(10)  

# Create a pie chart  
plt.figure(figsize=(8, 8))  
plt.pie(top_10_developers, labels=top_10_developers.index, autopct='%1.1f%%', startangle=140)  
plt.title("Top 10 Developers")  
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # Which category  has the highest number of apps?

# %%
# Find the category with the highest number of apps
top_category = df['Primary_Genre'].value_counts().idxmax()
top_count = df['Primary_Genre'].value_counts().max()

print(f"The category with the highest number of apps is '{top_category}' with {top_count} apps.")
# Out:
# The category with the highest number of apps is 'Games' with 193749 apps.

# %% [markdown]
# ----

# %% [markdown]
# # Top 10 categories

# %%
# Get the top 10 developers  
top_10_categories = df['Primary_Genre'].value_counts().head(10)  

# Create a pie chart  
plt.figure(figsize=(8, 8))  
plt.pie(top_10_developers, labels=top_10_categories.index, autopct='%1.1f%%', startangle=140)  
plt.title("Top 10 categories")  
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # Top 10 categories by value counts

# %%
# Count occurrences of each genre
genre_counts = df['Primary_Genre'].value_counts()

# Get the Top 10 genres
top_10_genres = genre_counts.head(10)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_genres.index, y=top_10_genres.values, palette="viridis")

# Labels & Title
plt.xlabel("Primary_Genre", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Top 10 Primary Genres by Count", fontsize=14)
plt.xticks(rotation=45)  # Rotate genre labels for better readability

# Show Plot
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4576\1338405768.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_genres.index, y=top_10_genres.values, palette="viridis")

# %% [markdown]
# ----

# %% [markdown]
# # Most Popular Developer (by Total Reviews)

# %%
top_reviewed_app=df.groupby('Developer')['Reviews'].sum().sort_values(ascending=False).head(10)
top_reviewed_app=pd.DataFrame(top_reviewed_app)
top_reviewed_app.reset_index(inplace=True)

# Plot
plt.figure(figsize=(12, 6))
plt.barh(top_reviewed_app['Developer'], top_reviewed_app['Reviews'], color='royalblue')
plt.xlabel("Total Reviews")
plt.ylabel("Developer")
plt.title("Top 10 Most Reviewed Developers")
plt.gca().invert_yaxis()  # Highest at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Released column

# %%
# Convert 'Released' column to datetime
df['Released'] = pd.to_datetime(df['Released'])

# Format the 'Released' column to day-month-year (DD MM YYYY)
df['Released'] = df['Released'].dt.strftime('%d %m %Y')

# Show the updated DataFrame
# print(df[['Released']])

# %%
df['Released'] = pd.to_datetime(df['Released'], errors='coerce')
df['Updated'] = pd.to_datetime(df['Updated'], errors='coerce')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4576\2555709870.py:1: UserWarning: Parsing dates in %d %m %Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Released'] = pd.to_datetime(df['Released'], errors='coerce')

# %%
# Extract Year for grouping
df['Year'] = df['Released'].dt.year

# Count the number of releases per year
release_count_by_year = df.groupby('Year').size()

# Plotting
plt.figure(figsize=(10, 6))
release_count_by_year.plot(kind='line', marker='o', color='b', linestyle='-', linewidth=2)

# Add title and labels
plt.title('Number of Releases per Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Releases', fontsize=12)
plt.grid(True)

# %%
# Get the first and last release dates
first_release = df['Released'].min()
last_release = df['Released'].max()

# Print the results
print(f"First release date: {first_release}")
print(f"Last release date: {last_release}")
# Out:
# First release date: 2008-09-24 00:00:00
# Last release date: 2022-04-09 00:00:00

# %% [markdown]
# ----

# %% [markdown]
# ##  Number of installs for free vs paid apps

# %%
# Count the number of free vs. paid apps
app_counts = df['Free'].value_counts()

# Rename the index for better readability
app_counts.index = ['Free', 'Paid']

# Plot the bar chart
plt.figure(figsize=(6, 4))
app_counts.plot(kind='bar', color=['blue', 'orange'])

# Add labels and title
plt.xlabel("App Type")
plt.ylabel("Count")
plt.title("Total Free vs. Paid Apps")
plt.xticks(rotation=0)

# Show the plot
plt.show()

# %%
df['Free'].value_counts()
# Out:
# Free
# True     1127384
# False     102992
# Name: count, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# # Which app has the largest "Size_MB" and what genre does it belong to?

# %%
# Find the row with the largest size in MB
largest_app = df.loc[df['Size_Mb'].idxmax()]

# Extract relevant details
app_name = largest_app['App_Name']
app_genre = largest_app['Primary_Genre']
size_mb = largest_app['Size_Mb']
is_free = "Free" if largest_app['Free'] == True else "Paid"
review_count = largest_app['Reviews']  # Assuming 'Reviews' is a proxy for installs

# Print the results
print(f"The app with the largest size is '{app_name}', which belongs to the '{app_genre}' genre, with a size of {size_mb:.2f} MB.")
print(f"It is a {is_free} app and has been reviewed {review_count} times.")
# Out:
# The app with the largest size is 'Metro Exodus', which belongs to the 'Games' genre, with a size of 76779.45 MB.
# It is a Paid app and has been reviewed 0 times.

# %% [markdown]
# ----

# %% [markdown]
# # Apps with respect to thier categories

# %%
df['Content_Rating'].value_counts()
# Out:
# Content_Rating
# 4+               980971
# 17+              124127
# 12+               89570
# 9+                35698
# Not yet rated        10
# Name: count, dtype: int64

# %% [markdown]
# **Apple’s content rating system classifies apps based on age suitability, primarily for parental guidance and user awareness.**
# - 4+ → Suitable for everyone, contains no objectionable material.
# - 9+ → Suitable for children 9 and above, may contain mild cartoon/fantasy violence.
# - 12+ → Suitable for teens 12 and above, may have mild sexual content, alcohol references, or simulated gambling.
# - 17+ → Suitable for adults, may contain strong violence, explicit sexual content, or unrestricted web access.
# - Not yet rated → Unrated, meaning Apple hasn’t assigned a rating yet

# %%
# Plot countplot
plt.figure(figsize=(8, 5))
sns.countplot(x='Content_Rating', data=df, palette='pastel')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.title('Count of Content Ratings')
plt.xlabel('Content Rating')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4576\2916209312.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Content_Rating', data=df, palette='pastel')

# %%
# pie chart using plotly
labels = ['4+','17+','12+','9+' , 'Not yet rated']
values = [980971, 124127, 89570, 35698 ,10]

# pull is given as a fraction of the pie radius
fig = go.Figure(data=[go.Pie(labels=labels, values=values, pull=[0.2, 0, 0, 0, 0])]) # to make pie chart with pull = 0.2 for 4+ 
fig.update_layout(
    width=800,
    height=600
    )

fig.update_layout(title_text='Content Rating Distribution ') # to make title
fig.update_layout(title_x=0.5) # to allign title to center
fig.update_layout(title_font=dict(family='Arial', size=25, color='black')) # to change title font size and color
fig.show()

# %%
# Get App category for rows with 'Not yet rated' in Content_Rating
no_rating_apps = df[df['Content_Rating'] == 'Not yet rated']['Primary_Genre']

# Print the result
print('App categories which are not yet rated:')
print('----------------------------------')
print(no_rating_apps.to_string(index=False))
print('----------------------------------')
print('This lack of ratings may indicate new releases or apps that have not undergone the evaluation process.')
# Out:
# App categories which are not yet rated:
# ----------------------------------
#      Business
#     Education
# Photo & Video
#        Sports
#       Finance
#       Finance
# Entertainment
#     Utilities
#    Navigation
#     Utilities
# ----------------------------------
# This lack of ratings may indicate new releases or apps that have not undergone the evaluation process.

# %%
# Get App_Name for rows with 'Not yet rated' in Content_Rating
no_rating_apps = df[df['Content_Rating'] == 'Not yet rated']['App_Name']

# Print the result
print('App names which are not yet rated:')
print('----------------------------------')
print(no_rating_apps.to_string(index=False))
print('----------------------------------')
print('This lack of ratings may indicate new releases or apps that have not undergone the evaluation process.')
# Out:
# App names which are not yet rated:
# ----------------------------------
#             Jazel
#   Financial Power
# IPTV Streamer Max
#          FL SPORT
#     FICA Collider
#        VAT Deluxe
#     Cowbell Fever
#       Table Clock
#       Speedometer
#      Paket Status
# ----------------------------------
# This lack of ratings may indicate new releases or apps that have not undergone the evaluation process.

# %% [markdown]
# ---

# %% [markdown]
#  # What is the most common app version among the apps in the dataset?

# %%
# Find the most common app version
most_common_version = df['Version'].mode()[0]

# Count how many apps have this version
version_count = (df['Version'] == most_common_version).sum()

# Print the result
print(f"The most common app version is '{most_common_version}', appearing in {version_count} apps.")
# Out:
# The most common app version is '1.0', appearing in 218134 apps.

# %% [markdown]
# ---

# %% [markdown]
# # How many apps have an "AppStore_Url" listed, and how many do not?

# %%
# Count apps with and without an AppStore URL
apps_with_url = df['AppStore_Url'].notna().sum()  # Count non-null values
apps_without_url = df['AppStore_Url'].isna().sum()  # Count null values

# Print results
print(f"Number of apps with an AppStore URL: {apps_with_url}")
print(f"Number of apps without an AppStore URL: {apps_without_url}")
# Out:
# Number of apps with an AppStore URL: 1230376
# Number of apps without an AppStore URL: 0

# %% [markdown]
# ---

# %% [markdown]
# # Time Difference b/w app released app updated

# %%
# Ensure 'Released' and 'Updated' are in datetime format
df['Released'] = pd.to_datetime(df['Released'], errors='coerce')
df['Updated'] = pd.to_datetime(df['Updated'], errors='coerce')

# Normalize both columns to tz-naive (remove timezone info)
df['Released'] = df['Released'].dt.tz_localize(None)
df['Updated'] = df['Updated'].dt.tz_localize(None)

# Calculate the time difference in days
df['Time_Difference'] = (df['Updated'] - df['Released']).dt.days
# Compute statistics
avg_time_diff = df['Time_Difference'].mean()
min_time_diff = df['Time_Difference'].min()
max_time_diff = df['Time_Difference'].max()
# Print the results
print(f"Average time difference between release and last update: {avg_time_diff:.2f} days")
print(f"Minimum time difference: {min_time_diff} days")
print(f"Maximum time difference: {max_time_diff} days")
# Out:
# Average time difference between release and last update: 596.11 days
# Minimum time difference: 0 days
# Maximum time difference: 4755 days

# %% [markdown]
# <span style="color: yellow; font-size: 350%; font-weight: bold;">SUMMARY OF PROJECT</span>

# %% [markdown]
# This project analyzes a comprehensive dataset from the Apple App Store, consisting of `1,230,376 `rows and `21` columns. The analysis begins with importing libraries and loading the dataset. The dataset includes a mix of data types, with 13 categorical (object) columns, 3 integer columns, 4 float columns, and 1 boolean column.
#
# During the data cleaning process, it was found that the `Developer_Website` column has the highest number of missing values, with `643,988 entries` left blank. Additionally, the `Price` column contains 490 missing values, and in total, six columns have missing data. Since most developers do not provide website information, the `Developer_Website` column was dropped, and the remaining missing values were handled using appropriate imputation techniques.
#
# A correlation analysis revealed some interesting relationships between features. A perfect correlation (1.000) exists between `Current_Version_Score` and `Average_User_Rating`, indicating that they vary in exactly the same manner. Most other correlations were weak, with values close to zero, suggesting minimal linear dependence. However, `Size_Mb` showed a slight positive correlation with `Price` (0.056), implying a marginal association. In contrast, `Price` exhibited a weak negative correlation with both `Current_Version_Score` and `Average_User_Rating` (-0.010), suggesting that higher-priced apps may have slightly lower ratings.
#
# Examining key statistics, the minimum app price is $0, while the highest-priced app costs `$999.99.` Free apps dominate the App Store, making up 91.5% of the dataset (1,127,384 apps), while only 8.5% (102,992 apps) are paid. Every app in the dataset has a corresponding App Store URL. Among the most-reviewed apps, Google LLC, Instagram, TikTok, and Spotify stand out as top performers.
#
# The dataset also highlights trends among developers and app categories. `ChowNow` is the leading developer, accounting for 29% of all apps, followed by `Touch2Success with 12%.` The most popular category is `Games,` which includes 193,749 apps. The dataset spans from September 24, 2008, to April 9, 2022, showing that app production increased significantly after 2008, peaking in 2020. The largest app in the dataset is` Metro Exodus `from the Games category, with a size of 76,779.45 MB. This app is paid and has received no reviews. There are four content rating categories, with 80% of apps rated 4+, making them suitable for all audiences. Business apps, however, often lack assigned content ratings.
#
# In terms of version and update patterns, the most frequently occurring app version is '1.0,' which appears in 218,134 apps. The average time between an app’s initial release and its last update is 596.11 days, with the shortest update cycle being 0 days and the longest spanning 4,755 days.
#
# **Overall, this analysis provides valuable insights into the Apple App Store ecosystem, highlighting trends in app pricing, categories, developer contributions, content ratings, and release patterns. These findings offer a deeper understanding of the app market and can serve as a guide for future development strategies**.

# %% [markdown]
# ---
